# %%
import os
import glob
import csv


def load_sensor_data():
    sensor_data = []
    sensor_files = glob.glob(os.path.join(os.getcwd(),"datasets","*.csv"))
    for sensor_file in sensor_files:
        with open(sensor_file) as data_file:
            data_reader = csv.DictReader(data_file,delimiter=",")
            for row in data_reader:
                sensor_data.append(row)
    return sensor_data



load_sensor_data()
# Out:
# [OrderedDict([('id', '1'),
#               ('date', '01/01/20'),
#               ('time', '11:04'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xffe'),
#               ('particulate', '6.20E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '2'),
#               ('date', '01/01/20'),
#               ('time', '20:29'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xff3'),
#               ('particulate', '6.30E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '3'),
#               ('date', '01/01/20'),
#               ('time', '22:03'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfef'),
#               ('particulate', '6.50E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '4'),
#               ('date', '01/01/20'),
#               ('time', '23:09'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfe5'),
#               ('particulate', '6.50E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '5'),
#               ('date', '01/02/20'),
#               ('time', '0:11'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfe3'),
#               ('particulate', '6.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '6'),
#               ('date', '01/02/20'),
#               ('time', '9:44'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfe2'),
#               ('particulate', '6.80E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '7'),
#               ('date', '01/02/20'),
#               ('time', '15:14'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfda'),
#               ('particulate', '6.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '8'),
#               ('date', '01/02/20'),
#               ('time', '20:53'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfd9'),
#               ('particulate', '6.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '9'),
#               ('date', '01/03/20'),
#               ('time', '2:08'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfd3'),
#               ('particulate', '6.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '10'),
#               ('date', '01/03/20'),
#               ('time', '4:12'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfd2'),
#               ('particulate', '7.00E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '11'),
#               ('date', '01/03/20'),
#               ('time', '4:21'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfcd'),
#               ('particulate', '7.20E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '12'),
#               ('date', '01/03/20'),
#               ('time', '6:50'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfc6'),
#               ('particulate', '7.30E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '13'),
#               ('date', '01/03/20'),
#               ('time', '22:26'),
#               ('temperature', '60'),
#               ('humidity', '0.8'),
#               ('energy_usage', '0xfc3'),
#               ('particulate', '7.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '14'),
#               ('date', '01/04/20'),
#               ('time', '0:44'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfc2'),
#               ('particulate', '7.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '15'),
#               ('date', '01/04/20'),
#               ('time', '4:18'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfc2'),
#               ('particulate', '7.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '16'),
#               ('date', '01/04/20'),
#               ('time', '8:40'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfbe'),
#               ('particulate', '7.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '17'),
#               ('date', '01/04/20'),
#               ('time', '9:02'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfbd'),
#               ('particulate', '7.70E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '18'),
#               ('date', '01/04/20'),
#               ('time', '11:09'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfac'),
#               ('particulate', '8.10E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '19'),
#               ('date', '01/04/20'),
#               ('time', '14:31'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfab'),
#               ('particulate', '9.30E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '20'),
#               ('date', '01/04/20'),
#               ('time', '16:53'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfa2'),
#               ('particulate', '9.40E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '21'),
#               ('date', '01/04/20'),
#               ('time', '17:42'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xfa1'),
#               ('particulate', '9.60E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '22'),
#               ('date', '01/04/20'),
#               ('time', '22:25'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf99'),
#               ('particulate', '9.70E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '23'),
#               ('date', '01/04/20'),
#               ('time', '22:55'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf98'),
#               ('particulate', '9.70E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '24'),
#               ('date', '01/05/20'),
#               ('time', '1:49'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf8e'),
#               ('particulate', '9.70E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '25'),
#               ('date', '01/05/20'),
#               ('time', '2:44'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf8b'),
#               ('particulate', '9.70E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '26'),
#               ('date', '01/05/20'),
#               ('time', '3:08'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf89'),
#               ('particulate', '9.80E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '27'),
#               ('date', '01/05/20'),
#               ('time', '3:40'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf89'),
#               ('particulate', '9.80E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '28'),
#               ('date', '01/05/20'),
#               ('time', '4:42'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf87'),
#               ('particulate', '9.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '29'),
#               ('date', '01/05/20'),
#               ('time', '5:56'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf85'),
#               ('particulate', '9.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '30'),
#               ('date', '01/05/20'),
#               ('time', '7:21'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf84'),
#               ('particulate', '9.90E+00'),
#               ('area', '1')]),
#  OrderedDict([('id', '31'),
#               ('date', '01/05/20'),
#               ('time', '7:49'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf83'),
#               ('particulate', '1.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '32'),
#               ('date', '01/05/20'),
#               ('time', '9:15'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf78'),
#               ('particulate', '1.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '33'),
#               ('date', '01/05/20'),
#               ('time', '9:49'),
#               ('temperature', '60'),
#               ('humidity', '0.79'),
#               ('energy_usage', '0xf64'),
#               ('particulate', '1.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '34'),
#               ('date', '01/05/20'),
#               ('time', '13:51'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf62'),
#               ('particulate', '1.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '35'),
#               ('date', '01/05/20'),
#               ('time', '19:12'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf5b'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '36'),
#               ('date', '01/05/20'),
#               ('time', '21:20'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf52'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '37'),
#               ('date', '01/05/20'),
#               ('time', '22:57'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf4d'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '38'),
#               ('date', '01/06/20'),
#               ('time', '0:37'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf4c'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '39'),
#               ('date', '01/06/20'),
#               ('time', '3:53'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf49'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '40'),
#               ('date', '01/06/20'),
#               ('time', '4:26'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf47'),
#               ('particulate', '1.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '41'),
#               ('date', '01/06/20'),
#               ('time', '18:20'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf46'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '42'),
#               ('date', '01/06/20'),
#               ('time', '23:00'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf3e'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '43'),
#               ('date', '01/07/20'),
#               ('time', '3:29'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf3e'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '44'),
#               ('date', '01/07/20'),
#               ('time', '3:38'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf3d'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '45'),
#               ('date', '01/07/20'),
#               ('time', '6:31'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf35'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '46'),
#               ('date', '01/07/20'),
#               ('time', '8:20'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf33'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '47'),
#               ('date', '01/07/20'),
#               ('time', '13:26'),
#               ('temperature', '60'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf2f'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '48'),
#               ('date', '01/07/20'),
#               ('time', '16:37'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf2a'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '49'),
#               ('date', '01/07/20'),
#               ('time', '17:11'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf25'),
#               ('particulate', '1.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '50'),
#               ('date', '01/07/20'),
#               ('time', '17:22'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf1d'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '51'),
#               ('date', '01/07/20'),
#               ('time', '21:11'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf16'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '52'),
#               ('date', '01/07/20'),
#               ('time', '22:29'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf12'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '53'),
#               ('date', '01/07/20'),
#               ('time', '22:34'),
#               ('temperature', '61'),
#               ('humidity', '0.78'),
#               ('energy_usage', '0xf11'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '54'),
#               ('date', '01/07/20'),
#               ('time', '23:55'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xf07'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '55'),
#               ('date', '01/08/20'),
#               ('time', '0:16'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xf06'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '56'),
#               ('date', '01/08/20'),
#               ('time', '0:23'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xf02'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '57'),
#               ('date', '01/08/20'),
#               ('time', '4:07'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xefb'),
#               ('particulate', '1.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '58'),
#               ('date', '01/08/20'),
#               ('time', '4:50'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xefa'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '59'),
#               ('date', '01/08/20'),
#               ('time', '7:40'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xef6'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '60'),
#               ('date', '01/08/20'),
#               ('time', '8:09'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeee'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '61'),
#               ('date', '01/08/20'),
#               ('time', '11:39'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeee'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '62'),
#               ('date', '01/08/20'),
#               ('time', '12:56'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xee6'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '63'),
#               ('date', '01/08/20'),
#               ('time', '13:11'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xee6'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '64'),
#               ('date', '01/08/20'),
#               ('time', '14:31'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xee3'),
#               ('particulate', '1.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '65'),
#               ('date', '01/08/20'),
#               ('time', '14:59'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xedf'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '66'),
#               ('date', '01/08/20'),
#               ('time', '15:41'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xede'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '67'),
#               ('date', '01/08/20'),
#               ('time', '21:20'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xede'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '68'),
#               ('date', '01/08/20'),
#               ('time', '21:36'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xed6'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '69'),
#               ('date', '01/08/20'),
#               ('time', '22:41'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xecd'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '70'),
#               ('date', '01/09/20'),
#               ('time', '1:30'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeca'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '71'),
#               ('date', '01/09/20'),
#               ('time', '7:37'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xec6'),
#               ('particulate', '1.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '72'),
#               ('date', '01/09/20'),
#               ('time', '10:34'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xec5'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '73'),
#               ('date', '01/09/20'),
#               ('time', '13:24'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeb9'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '74'),
#               ('date', '01/09/20'),
#               ('time', '17:19'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeb8'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '75'),
#               ('date', '01/09/20'),
#               ('time', '18:03'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeb6'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '76'),
#               ('date', '01/09/20'),
#               ('time', '22:07'),
#               ('temperature', '61'),
#               ('humidity', '0.77'),
#               ('energy_usage', '0xeb2'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '77'),
#               ('date', '01/10/20'),
#               ('time', '4:49'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xeb2'),
#               ('particulate', '1.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '78'),
#               ('date', '01/10/20'),
#               ('time', '10:57'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xeae'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '79'),
#               ('date', '01/10/20'),
#               ('time', '13:01'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xeae'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '80'),
#               ('date', '01/10/20'),
#               ('time', '16:32'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xead'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '81'),
#               ('date', '01/10/20'),
#               ('time', '20:00'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xea8'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '82'),
#               ('date', '01/11/20'),
#               ('time', '7:49'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xea5'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '83'),
#               ('date', '01/11/20'),
#               ('time', '10:08'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe9e'),
#               ('particulate', '1.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '84'),
#               ('date', '01/11/20'),
#               ('time', '11:58'),
#               ('temperature', '61'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe97'),
#               ('particulate', '1.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '85'),
#               ('date', '01/11/20'),
#               ('time', '16:50'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe96'),
#               ('particulate', '1.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '86'),
#               ('date', '01/11/20'),
#               ('time', '16:59'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe84'),
#               ('particulate', '1.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '87'),
#               ('date', '01/11/20'),
#               ('time', '19:49'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe70'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '88'),
#               ('date', '01/11/20'),
#               ('time', '21:05'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe6f'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '89'),
#               ('date', '01/11/20'),
#               ('time', '23:18'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe6e'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '90'),
#               ('date', '01/12/20'),
#               ('time', '5:30'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe6e'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '91'),
#               ('date', '01/12/20'),
#               ('time', '5:54'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe64'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '92'),
#               ('date', '01/12/20'),
#               ('time', '9:29'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe5a'),
#               ('particulate', '2.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '93'),
#               ('date', '01/12/20'),
#               ('time', '12:50'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe59'),
#               ('particulate', '2.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '94'),
#               ('date', '01/12/20'),
#               ('time', '12:52'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe55'),
#               ('particulate', '2.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '95'),
#               ('date', '01/12/20'),
#               ('time', '14:42'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe49'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '96'),
#               ('date', '01/12/20'),
#               ('time', '16:25'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe48'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '97'),
#               ('date', '01/12/20'),
#               ('time', '16:43'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe3d'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '98'),
#               ('date', '01/12/20'),
#               ('time', '18:11'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe33'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '99'),
#               ('date', '01/12/20'),
#               ('time', '21:16'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe33'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '100'),
#               ('date', '01/13/20'),
#               ('time', '3:20'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe31'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '101'),
#               ('date', '01/13/20'),
#               ('time', '5:34'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe2b'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '102'),
#               ('date', '01/13/20'),
#               ('time', '8:03'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe29'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '103'),
#               ('date', '01/13/20'),
#               ('time', '8:19'),
#               ('temperature', '62'),
#               ('humidity', '0.76'),
#               ('energy_usage', '0xe22'),
#               ('particulate', '2.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '104'),
#               ('date', '01/13/20'),
#               ('time', '13:42'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xe1d'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '105'),
#               ('date', '01/13/20'),
#               ('time', '14:49'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xe19'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '106'),
#               ('date', '01/13/20'),
#               ('time', '15:04'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xe0f'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '107'),
#               ('date', '01/13/20'),
#               ('time', '19:47'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xe0c'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '108'),
#               ('date', '01/13/20'),
#               ('time', '21:53'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdfc'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '109'),
#               ('date', '01/13/20'),
#               ('time', '22:51'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdfc'),
#               ('particulate', '2.30E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '110'),
#               ('date', '01/14/20'),
#               ('time', '4:19'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdfa'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '111'),
#               ('date', '01/14/20'),
#               ('time', '5:24'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdf8'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '112'),
#               ('date', '01/14/20'),
#               ('time', '7:12'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdf7'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '113'),
#               ('date', '01/14/20'),
#               ('time', '7:24'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdeb'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '114'),
#               ('date', '01/14/20'),
#               ('time', '7:46'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xde6'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '115'),
#               ('date', '01/14/20'),
#               ('time', '8:20'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xde1'),
#               ('particulate', '2.40E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '116'),
#               ('date', '01/14/20'),
#               ('time', '9:10'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xde0'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '117'),
#               ('date', '01/14/20'),
#               ('time', '12:44'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdd5'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '118'),
#               ('date', '01/14/20'),
#               ('time', '20:04'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdd3'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '119'),
#               ('date', '01/15/20'),
#               ('time', '4:31'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdd2'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '120'),
#               ('date', '01/15/20'),
#               ('time', '7:25'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdd1'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '121'),
#               ('date', '01/15/20'),
#               ('time', '8:13'),
#               ('temperature', '62'),
#               ('humidity', '0.75'),
#               ('energy_usage', '0xdd1'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '122'),
#               ('date', '01/15/20'),
#               ('time', '13:40'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdcd'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '123'),
#               ('date', '01/15/20'),
#               ('time', '15:01'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdcb'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '124'),
#               ('date', '01/15/20'),
#               ('time', '15:56'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdca'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '125'),
#               ('date', '01/16/20'),
#               ('time', '1:04'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdc6'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '126'),
#               ('date', '01/16/20'),
#               ('time', '2:14'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdc3'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '127'),
#               ('date', '01/16/20'),
#               ('time', '11:10'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdc3'),
#               ('particulate', '2.50E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '128'),
#               ('date', '01/16/20'),
#               ('time', '11:46'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdc2'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '129'),
#               ('date', '01/16/20'),
#               ('time', '11:56'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdbb'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '130'),
#               ('date', '01/16/20'),
#               ('time', '12:40'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdad'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '131'),
#               ('date', '01/16/20'),
#               ('time', '13:12'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdac'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '132'),
#               ('date', '01/16/20'),
#               ('time', '13:53'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xdab'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '133'),
#               ('date', '01/16/20'),
#               ('time', '14:43'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xda4'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '134'),
#               ('date', '01/16/20'),
#               ('time', '14:50'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xda1'),
#               ('particulate', '2.60E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '135'),
#               ('date', '01/16/20'),
#               ('time', '17:15'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd98'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '136'),
#               ('date', '01/16/20'),
#               ('time', '20:53'),
#               ('temperature', '62'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd97'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '137'),
#               ('date', '01/17/20'),
#               ('time', '0:55'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd94'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '138'),
#               ('date', '01/17/20'),
#               ('time', '2:05'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd88'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '139'),
#               ('date', '01/17/20'),
#               ('time', '3:24'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd87'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '140'),
#               ('date', '01/17/20'),
#               ('time', '4:49'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd7f'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '141'),
#               ('date', '01/17/20'),
#               ('time', '7:17'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd7c'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '142'),
#               ('date', '01/17/20'),
#               ('time', '7:26'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd7b'),
#               ('particulate', '2.70E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '143'),
#               ('date', '01/17/20'),
#               ('time', '8:37'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd77'),
#               ('particulate', '2.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '144'),
#               ('date', '01/17/20'),
#               ('time', '13:20'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd77'),
#               ('particulate', '2.80E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '145'),
#               ('date', '01/17/20'),
#               ('time', '16:23'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd76'),
#               ('particulate', '2.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '146'),
#               ('date', '01/17/20'),
#               ('time', '19:23'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd75'),
#               ('particulate', '2.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '147'),
#               ('date', '01/17/20'),
#               ('time', '23:58'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd75'),
#               ('particulate', '2.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '148'),
#               ('date', '01/18/20'),
#               ('time', '1:20'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd74'),
#               ('particulate', '2.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '149'),
#               ('date', '01/18/20'),
#               ('time', '5:57'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd72'),
#               ('particulate', '2.90E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '150'),
#               ('date', '01/18/20'),
#               ('time', '10:00'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd72'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '151'),
#               ('date', '01/18/20'),
#               ('time', '14:19'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd6e'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '152'),
#               ('date', '01/18/20'),
#               ('time', '16:21'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd6c'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '153'),
#               ('date', '01/18/20'),
#               ('time', '20:39'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd6b'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '154'),
#               ('date', '01/18/20'),
#               ('time', '21:13'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd67'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '155'),
#               ('date', '01/19/20'),
#               ('time', '2:32'),
#               ('temperature', '63'),
#               ('humidity', '0.74'),
#               ('energy_usage', '0xd62'),
#               ('particulate', '3.00E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '156'),
#               ('date', '01/19/20'),
#               ('time', '8:05'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd61'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '157'),
#               ('date', '01/19/20'),
#               ('time', '17:04'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd61'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '158'),
#               ('date', '01/19/20'),
#               ('time', '17:49'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd5e'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '159'),
#               ('date', '01/19/20'),
#               ('time', '18:44'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd5d'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '160'),
#               ('date', '01/19/20'),
#               ('time', '20:48'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd54'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '161'),
#               ('date', '01/20/20'),
#               ('time', '1:00'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd51'),
#               ('particulate', '3.10E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '162'),
#               ('date', '01/20/20'),
#               ('time', '4:03'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd4c'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '163'),
#               ('date', '01/20/20'),
#               ('time', '6:01'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd47'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '164'),
#               ('date', '01/20/20'),
#               ('time', '12:03'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd40'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '165'),
#               ('date', '01/20/20'),
#               ('time', '13:37'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd40'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '166'),
#               ('date', '01/20/20'),
#               ('time', '14:07'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd36'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '167'),
#               ('date', '01/20/20'),
#               ('time', '22:32'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd2e'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '168'),
#               ('date', '01/21/20'),
#               ('time', '3:21'),
#               ('temperature', '63'),
#               ('humidity', '0.73'),
#               ('energy_usage', '0xd2d'),
#               ('particulate', '3.20E+01'),
#               ('area', '1')]),
#  OrderedDict([('id', '169'),
#               ('date', '01/21/20'),
#               ('time', '3:45'),
#               ('temperature', '63'),
# ...
#  OrderedDict([('id', '945'),
#               ('date', '05/04/20'),
#               ('time', '12:29'),
#               ('temperature', '79'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0e8'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '946'),
#               ('date', '05/04/20'),
#               ('time', '13:00'),
#               ('temperature', '79'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0e5'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '947'),
#               ('date', '05/04/20'),
#               ('time', '17:39'),
#               ('temperature', '79'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0db'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '948'),
#               ('date', '05/04/20'),
#               ('time', '17:45'),
#               ('temperature', '79'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0d9'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '949'),
#               ('date', '05/04/20'),
#               ('time', '19:39'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0d8'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '950'),
#               ('date', '05/05/20'),
#               ('time', '7:58'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0d3'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '951'),
#               ('date', '05/05/20'),
#               ('time', '14:22'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0d0'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '952'),
#               ('date', '05/05/20'),
#               ('time', '18:19'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0ce'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '953'),
#               ('date', '05/05/20'),
#               ('time', '18:50'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0cb'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '954'),
#               ('date', '05/05/20'),
#               ('time', '18:51'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0c6'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '955'),
#               ('date', '05/05/20'),
#               ('time', '21:55'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0b7'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '956'),
#               ('date', '05/06/20'),
#               ('time', '1:00'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0b6'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '957'),
#               ('date', '05/06/20'),
#               ('time', '1:28'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x0ae'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '958'),
#               ('date', '05/06/20'),
#               ('time', '7:42'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x09e'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '959'),
#               ('date', '05/06/20'),
#               ('time', '11:54'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x09d'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '960'),
#               ('date', '05/06/20'),
#               ('time', '14:30'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x09c'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '961'),
#               ('date', '05/06/20'),
#               ('time', '20:58'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x09c'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '962'),
#               ('date', '05/06/20'),
#               ('time', '21:48'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x09a'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '963'),
#               ('date', '05/07/20'),
#               ('time', '7:37'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x08a'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '964'),
#               ('date', '05/07/20'),
#               ('time', '9:06'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x088'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '965'),
#               ('date', '05/07/20'),
#               ('time', '9:41'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x081'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '966'),
#               ('date', '05/07/20'),
#               ('time', '10:07'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x07f'),
#               ('particulate', '1.50E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '967'),
#               ('date', '05/07/20'),
#               ('time', '13:12'),
#               ('temperature', '80'),
#               ('humidity', '0.42'),
#               ('energy_usage', '0x07a'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '968'),
#               ('date', '05/07/20'),
#               ('time', '17:20'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x072'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '969'),
#               ('date', '05/07/20'),
#               ('time', '22:22'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x072'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '970'),
#               ('date', '05/08/20'),
#               ('time', '6:26'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x071'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '971'),
#               ('date', '05/08/20'),
#               ('time', '23:06'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06f'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '972'),
#               ('date', '05/08/20'),
#               ('time', '23:20'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06f'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '973'),
#               ('date', '05/08/20'),
#               ('time', '23:57'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06f'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '974'),
#               ('date', '05/09/20'),
#               ('time', '0:07'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06d'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '975'),
#               ('date', '05/09/20'),
#               ('time', '1:36'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06d'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '976'),
#               ('date', '05/09/20'),
#               ('time', '5:43'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x06a'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '977'),
#               ('date', '05/09/20'),
#               ('time', '12:02'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x069'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '978'),
#               ('date', '05/09/20'),
#               ('time', '13:00'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x05b'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '979'),
#               ('date', '05/09/20'),
#               ('time', '14:48'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x05b'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '980'),
#               ('date', '05/09/20'),
#               ('time', '19:53'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x05a'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '981'),
#               ('date', '05/09/20'),
#               ('time', '21:32'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x058'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '982'),
#               ('date', '05/09/20'),
#               ('time', '21:36'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x056'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '983'),
#               ('date', '05/09/20'),
#               ('time', '22:51'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x051'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '984'),
#               ('date', '05/10/20'),
#               ('time', '4:40'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x04f'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '985'),
#               ('date', '05/10/20'),
#               ('time', '6:58'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x04d'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '986'),
#               ('date', '05/10/20'),
#               ('time', '7:26'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x04c'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '987'),
#               ('date', '05/10/20'),
#               ('time', '7:32'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x045'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '988'),
#               ('date', '05/10/20'),
#               ('time', '8:51'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x037'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '989'),
#               ('date', '05/10/20'),
#               ('time', '16:53'),
#               ('temperature', '80'),
#               ('humidity', '0.41'),
#               ('energy_usage', '0x036'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '990'),
#               ('date', '05/10/20'),
#               ('time', '18:12'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x036'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '991'),
#               ('date', '05/10/20'),
#               ('time', '19:25'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x033'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '992'),
#               ('date', '05/10/20'),
#               ('time', '21:02'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x02a'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '993'),
#               ('date', '05/10/20'),
#               ('time', '21:41'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x029'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '994'),
#               ('date', '05/11/20'),
#               ('time', '1:20'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x025'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '995'),
#               ('date', '05/11/20'),
#               ('time', '6:31'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x022'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '996'),
#               ('date', '05/11/20'),
#               ('time', '7:54'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x01f'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '997'),
#               ('date', '05/11/20'),
#               ('time', '9:37'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x014'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '998'),
#               ('date', '05/11/20'),
#               ('time', '10:45'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x013'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '999'),
#               ('date', '05/11/20'),
#               ('time', '12:00'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x006'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  OrderedDict([('id', '1000'),
#               ('date', '05/11/20'),
#               ('time', '23:03'),
#               ('temperature', '80'),
#               ('humidity', '0.4'),
#               ('energy_usage', '0x001'),
#               ('particulate', '1.60E+02'),
#               ('area', '1')]),
#  ...]

# %%
from datetime import datetime
from datetime import date


class HouseInfo:
    def __init__(self, data):
        self.data = data

    def get_data_by_area(self, field, rec_area=0):
        field_data = []
        for record in self.data:
            if rec_area == 0:
                field_data.append(record[field])
            elif rec_area == int(record['area']):
                field_data.append(record['area'])
        return field_data

    def get_data_by_date(self, field, rec_date=date.today()):
        field_data = []
        for record in self.data:
            if rec_date.strftime("%m/%d/%y") == record['date']:
                field_data.append(record[field])
        return field_data
